# %%
# %matplotlib notebook 
import numpy as np
import matplotlib.pyplot as plt

# %%
## %matplotlib notebook es para que nos de los graficos de manera interactiva debajo de cada una de las celdas

# %%
x = np.arange(-6, 6)

y_1 = 3*x+5
y_2 = -x+3
y_3 = 2*x+1

# %%
plt.figure()
plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.xlim(-8, 8)
plt.ylim(-8, 8)

plt.axvline(x=0, color="grey")
plt.axhline(y=0, color="grey")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## Sistema sobredeterminado, osea que tiene mas ecuaciones que varibles.

# %%
x = np.arange(-6, 6)

y_2 = -1*x+3
y_3 = 2*x+1

# %%
plt.figure()
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.xlim(-8, 8)
plt.ylim(-8, 8)

plt.axvline(x=0, color="grey")
plt.axhline(y=0, color="grey")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.arange(-6, 6)

y_3 = 2*x+1

# %%
plt.figure()
plt.plot(x, y_3)

plt.xlim(-8, 8)
plt.ylim(-8, 8)

plt.axvline(x=0, color="grey")
plt.axhline(y=0, color="grey")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## Multiple soluciones por que es una recta, cualquier punto puede ser una solucion.
