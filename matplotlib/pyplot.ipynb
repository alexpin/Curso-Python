# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# Para cambiarle el color 'r', donde r es red, y, b
# o = Marcadores en forma de
# plot = Grafico de lineas

# %%
plt.plot(x,y, 'bo')
plt.show()

# %% [markdown]
# Roja y con x

# %%
plt.plot(x,y, 'rx')
plt.show()

# %% [markdown]
# Roja con squads y una continuidad, con el ; evitamos usar el .show

# %%
plt.plot(x,y, 'rs-');

# %%
plt.plot(x,y, 'gD:');

# %% [markdown]
# Graficar x en un histograma

# %%
plt.hist(x);

# %%
plt.pie(x);

# %% [markdown]
# Relacion entre las dos variabbles.

# %%
plt.scatter(x,y);

# %% [markdown]
# Distribucion de los datos

# %%
plt.boxplot(x);

# %% [markdown]
# plot(x, y) — Matplotlib 3.5.1 documentation
#
# https://matplotlib.org/stable/plot_types/basic/plot.html#sphx-glr-plot-types-basic-plot-py
#
#
# Pyplot.ipynb - Google Drive
#
# https://drive.google.com/file/d/1hjZSk8ZC_9HwtUAZWLUZhJ2ETSUfG_9B/view?usp=sharing
