# %% [markdown]
# <a href="https://colab.research.google.com/github/alexpin/Curso-Python/blob/master/matplotlib/joinplot_pairplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', hue='sex');

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', hue='sex', kind='hist', marginal_ticks=True, marginal_kws=dict(bins=25, fill=False, multiple='dodge'));

# %% [markdown]
# marginal_ticks -> Agrega una escala adicional a los histogramas de los ejes.
# marginal_kws -> Afecta a los bins de los histogramas de los ejes(bins es la forma de medir los ejes)

# %%
sns.pairplot(data=tips, hue='sex', palette='coolwarm', corner=True, kind='scatter');

# %% [markdown]
# Correlacion para variables numericas.

# %% [markdown]
# Corner -> Para evitar relaciones o graficos duplicados
